# %%
"""from question1 import HockeySeason

season_data = HockeySeason(2016, 2020)
season_data.download()
               """
# Out:
# 'from question1 import HockeySeason\n\nseason_data = HockeySeason(2016, 2020)\nseason_data.download()\n               '

# %%
from question1 import get_play_by_play_season_gameType
get_play_by_play_season_gameType("2016","02","data_saved/play_by_play")
get_play_by_play_season_gameType("2016","03","data_saved/play_by_play")
get_play_by_play_season_gameType("2017","02","data_saved/play_by_play")
get_play_by_play_season_gameType("2017","03","data_saved/play_by_play")
get_play_by_play_season_gameType("2018","02","data_saved/play_by_play")
get_play_by_play_season_gameType("2018","03","data_saved/play_by_play")
get_play_by_play_season_gameType("2019","02","data_saved/play_by_play")
get_play_by_play_season_gameType("2019","03","data_saved/play_by_play")
get_play_by_play_season_gameType("2020","02","data_saved/play_by_play")
get_play_by_play_season_gameType("2020","03","data_saved/play_by_play")
# Out:
# 100%|██████████| 1230/1230 [02:55<00:00,  7.02it/s]
# 100%|██████████| 1230/1230 [01:17<00:00, 15.94it/s]
# 100%|██████████| 1271/1271 [02:46<00:00,  7.62it/s]
# 100%|██████████| 1271/1271 [01:20<00:00, 15.83it/s]
# 100%|██████████| 1271/1271 [01:55<00:00, 10.97it/s]
# 100%|██████████| 1271/1271 [01:15<00:00, 16.83it/s]
# 100%|██████████| 1271/1271 [01:51<00:00, 11.38it/s]
# 100%|██████████| 1271/1271 [01:16<00:00, 16.63it/s]
# 100%|██████████| 1271/1271 [02:02<00:00, 10.40it/s]
# 100%|██████████| 1271/1271 [01:15<00:00, 16.74it/s]

# %%
import ipywidgets as widgets
import question2

saison = widgets.IntSlider(
            value=2016,
            min=2016,
            max=2020,
            step=1,
            description='Saisons:', 
            disabled=False,
            continuous_update=False,
            orientation='horizontal',
            readout=True,
            readout_format='d')
types = widgets.SelectMultiple(
            options = ['Saison régulière', 'Séries éliminatoires'],
            value=['Saison régulière'],
            description='Type de partie',
            disabled=False)
num = widgets.Text(
            value="",
            placeholder='Type something...',
            description='Entrer le numéro de match',
            disabled=False)
event = widgets.Text(
            value="",
            placeholder='Type something...',
            description='Entrer le numéro d evenement',
            disabled=False)

widgets.interact(question2.match_info, s = saison, t = types, n = num, e = event)
# Out:
# interactive(children=(IntSlider(value=2016, continuous_update=False, description='Saisons:', max=2020, min=201…
# <function question2.match_info(s, t, n, e)>

# %%
from question4 import *
directory2018 = r'data_saved/play_by_play/2018'
"""directory2019 = r'data_saved/play_by_play/2019'
directory2020 = r'data_saved/play_by_play/2020'"""
df2018 = create_full_df(directory=directory2018)
"""df2019 = create_full_df(directory=directory2019)
df2020 = create_full_df(directory=directory2020)"""
# Out:
# 'df2019 = create_full_df(directory=directory2019)\ndf2020 = create_full_df(directory=directory2020)'

# %%
import question6
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
print("Here is the average location of shots and goals per match:")
avg_shot_hour = question6.league_avg_shot_hour(df2018)
print("There is in average "+str(avg_shot_hour)+".")
# Out:
# Here is the average location of shots and goals per match:
# x: 60.72831542053354 y: -0.1867394822948567
# There is in average 63.285924834193075.

# %%
"""question6.excess_shot_rate_hour(df2018)"""
excess_hour=question6.excess_shot_rate_hour(df2018)
print(excess_hour.describe())
print(excess_hour.head())
# Out:
# count    31.000000
# mean     -0.084900
# std       3.477515
# min      -7.481047
# 25%      -2.719057
# 50%       0.079929
# 75%       2.743020
# max       5.882614
# dtype: float64
# Team_of_Shooter
# ANA   -7.481047
# ARI   -1.359096
# BOS    2.431056
# BUF    3.079929
# CAR    4.590364
# dtype: float64

# %%
df = question6.KernelD(df2018)
print(df.head())
# Out:
#   Shot_or_Goal  X_Coordinate  Y_Coordinate  KDensity
# 0         Shot         -57.0          29.0  0.025056
# 1         Shot         -84.0          -7.0  0.095669
# 2         Shot         -57.0         -19.0  0.018223
# 3         Shot         -81.0           8.0  0.082002
# 4         Shot          78.0         -10.0  0.050112

# %%
#parcourir les tirs et buts de toutes les équipes pour la saison 2017.
question6.print_cordonne_tir_eachTeam("2017")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="242cd6fc-22b7-4ab8-8d8a-d155b3a165c1" class="plotly-graph-div" style="height:467px; width:550px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("242cd6fc-22b7-4ab8-8d8a-d155b3a165c1")) {                    Plotly.newPlot(                        "242cd6fc-22b7-4ab8-8d8a-d155b3a165c1",                        [{"marker":{"color":"red","size":3},"mode":"markers","showlegend":false,"visible":true,"x":[121.0,104.5,137.5,93.5,121.0,16.5,71.5,5.5,88.0,27.5,110.0,121.0,121.0,88.0,77.00000000000001,60.5,38.50000000000001,93.5,77.00000000000001,60.5,115.5,22.0,55.0,22.0,88.0,38.50000000000001,104.5,71.5],"y":[238.99411764705883,277.4529411764706,293.93529411764706,299.4294117647059,271.95882352941175,238.99411764705883,321.40588235294115,332.3941176470588,304.9235294117647,249.98235294117646,304.9235294117647,326.9,233.5,282.9470588235294,337.88823529411764,233.5,332.3941176470588,238.99411764705883,277.4529411764706,304.9235294117647,249.98235294117646,249.98235294117646,244.48823529411766,277.4529411764706,282.9470588235294,260.97058823529414,244.48823529411766,282.9470588235294],"type":"scatter"},{"marker":{"color":"red","size":3},"mode":"markers","showlegend":false,"visible":true,"x":[104.5,126.5,33.0,11.0,60.5,5.5,55.0,132.0,49.5,126.5,5.5,5.5,115.5,121.0,22.0,66.0,55.0,27.5,121.0,5.5,60.5,126.5,93.5,104.5,104.5],"y":[359.86470588235295,414.8058823529412,370.8529411764706,420.3,370.8529411764706,365.3588235294118,365.3588235294118,464.2529411764706,387.3352941176471,370.8529411764706,409.31176470588235,447.7705882352941,442.27647058823527,403.8176470588235,447.7705882352941,403.8176470588235,447.7705882352941,359.86470588235295,425.7941176470588,442.27647058823527,431.2882352941176,420.3,431.2882352941176,398.32352941176475,409.31176470588235],"type":"scatter"},{"marker":{"color":"red","size":3},"mode":"markers","showlegend":false,"visible":true,"x":